# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketyadav29/DT_Practice/blob/main/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basics**

# %%
a=5
b=3
print(a+b)
# Out:
# 8

# %%
print("Hello World")
# Out:
# Hello World
