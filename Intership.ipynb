# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniketyadav29/DT_Practice/blob/main/Intership.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basics**

# %%
a=34
b=45
c=a+b
print(c)
# Out:
# 79
